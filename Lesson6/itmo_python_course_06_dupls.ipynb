# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Python_ITMO_2025/Занятие 5 - 07.10.2025/Verizon.csv', sep=';')
data.head()
# Out:
#   longdist internat   local int_disc    billtype  pay   age     gender  \
# 0     8.62      NaN    8.49      Нет   Бюджетный   CH  43.0    Мужской
# 1    21.27      0.0  218,12      Нет   Бюджетный   CH  60.0        NaN
# 2     6,13      0.0     NaN       Да         NaN  NaN  25.0    Женский
# 3    16.46      0.0   57,66       Да  Бесплатный  NaN  93.0    Женский
# 4      NaN      0.0   16,01       Да  Бесплатный   CC  68.0  Женский&*
#
#      marital  children   income  churn
# 0     _Женат       0.0  33935.8      0
# 1  _Одинокий       2.0  95930,6      1
# 2        NaN       2.0   295,34      1
# 3   Одинокий       0.0      NaN      1
# 4        NaN       0.0  99832,9      1

# %%
data.shape
# Out:
# (1477, 12)

# %%
data.duplicated().sum()
# Out:
# np.int64(2)

# %%
data[data.duplicated(subset=['longdist', 'billtype'])]
# Out:
#      longdist internat   local int_disc    billtype   pay   age   gender  \
# 11        NaN      0.0    3.42      Нет  Бесплатный    CC  26.0  Мужской
# 74        0.0      0.0    1.38      Нет  Бесплатный    CC  64.0  Мужской
# 79        0.0      0.0    4.83      Нет  Бесплатный    CC  59.0  Мужской
# 84        0.0      0.0    2.02      Нет  Бесплатный    CC  25.0  Женский
# 92        0.0      0.0    0.36      Нет   Бюджетный    CC  25.0  Мужской
# ...       ...      ...     ...      ...         ...   ...   ...      ...
# 1467      0.0      0.0    1.18       Да   Бюджетный    CC  79.0  Мужской
# 1470      0.0      0.0    4.76      Нет  Бесплатный    CC  27.0  Женский
# 1474      0.0      0.0    1.65      Нет  Бесплатный  Auto  88.0  Женский
# 1475    12.86     0.04  156.51       Да   Бюджетный    CC  18.0  Женский
# 1476    14.77      0.0   30.42      Нет  Бесплатный    CH  86.0  Мужской
#
#        marital  children   income  churn
# 11       Женат       0.0  10095.8      1
# ...

# %%
data.drop_duplicates(subset=None, keep='first',
                     inplace=True)
# Out:
#      longdist internat   local int_disc    billtype   pay   age     gender  \
# 0        8.62      NaN    8.49      Нет   Бюджетный    CH  43.0    Мужской
# 1       21.27      0.0  218,12      Нет   Бюджетный    CH  60.0        NaN
# 2        6,13      0.0     NaN       Да         NaN   NaN  25.0    Женский
# 3       16.46      0.0   57,66       Да  Бесплатный   NaN  93.0    Женский
# 4         NaN      0.0   16,01       Да  Бесплатный    CC  68.0  Женский&*
# ...       ...      ...     ...      ...         ...   ...   ...        ...
# 1472    25.46      0.0   43.91       Да  Бесплатный  Auto  46.0    Мужской
# 1473     8.46      0.0   22.65      Нет  Бесплатный    CC  51.0    Женский
# 1474      0.0      0.0    1.65      Нет  Бесплатный  Auto  88.0    Женский
# 1475    12.86     0.04  156.51       Да   Бюджетный    CC  18.0    Женский
# 1476    14.77      0.0   30.42      Нет  Бесплатный    CH  86.0    Мужской
#
#         marital  children   income  churn
# ...

# %%
data[data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [longdist, internat, local, int_disc, billtype, pay, age, gender, marital, children, income, churn]
# Index: []

# %%
data.shape
# Out:
# (1475, 12)
