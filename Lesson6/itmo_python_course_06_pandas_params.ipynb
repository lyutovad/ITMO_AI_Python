# %% [markdown]
# ### Настройки вывода
#
# [Pandas docs](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html)

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Python_ITMO_2025/Занятие 5 - 07.10.2025/laptops_10.csv')

# %%
df.head(100)
# Out:
#    Company                                     Product            TypeName  \
# 0    Apple                                 MacBook Pro           Ultrabook
# 1    Apple                                 Macbook Air           Ultrabook
# 2       HP                                      250 G6            Notebook
# 3    Apple                                 MacBook Pro           Ultrabook
# 4    Apple                                 MacBook Pro           Ultrabook
# ..     ...                                         ...                 ...
# 95    Acer                                      Spin 5  2 in 1 Convertible
# 96    Dell                               Inspiron 3567            Notebook
# 97    Dell                               Inspiron 3567            Notebook
# 98    Asus  X541UV-DM1439T (i3-7100U/6GB/256GB/GeForce            Notebook
# 99      HP                             Omen 15-ce007nv              Gaming
#
#     Inches                          Cpu   Ram                           Gpu  \
# 0     13.3         Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640
# 1     13.3         Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000
# 2     15.6   Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620
# 3     15.4         Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455
# 4     13.3         Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650
# ..     ...                          ...   ...                           ...
# 95    13.3   Intel Core i5 8250U 1.6GHz   8GB        Intel UHD Graphics 620
# 96    15.6   Intel Core i7 7500U 2.7GHz   8GB            AMD Radeon R5 M430
# 97    15.6     Intel Core i3 6006U 2GHz   4GB            AMD Radeon R5 M430
# 98    15.6   Intel Core i3 7100U 2.4GHz   6GB           Nvidia GeForce 920M
# 99    15.6  Intel Core i7 7700HQ 2.8GHz  12GB       Nvidia GeForce GTX 1050
#
#          OpSys  Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type
# 0        macOS    1.37      1339.69       Intel            128           SSD
# 1        macOS    1.34       898.94       Intel            128  FlashStorage
# 2        No OS    1.86       575.00       Intel            256           SSD
# 3        macOS    1.83      2537.45       Intel            512           SSD
# 4        macOS    1.37      1803.60       Intel            256           SSD
# ..         ...     ...          ...         ...            ...           ...
# 95  Windows 10    1.50       847.00       Intel            256           SSD
# 96       Linux    2.20       599.90       Intel           1024           HDD
# 97       Linux    2.20       485.00       Intel            256           SSD
# 98  Windows 10    2.00       577.00       Intel            256           SSD
# 99  Windows 10    2.62      1249.00       Intel            128           HDD
#
# [100 rows x 13 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows = 100

pd.options.display.max_rows
# Out:
# 100

# %%
df.head(10)
# Out:
#   Company          Product   TypeName  Inches                         Cpu  \
# 0   Apple      MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz
# 1   Apple      Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz
# 2      HP           250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz
# 3   Apple      MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz
# 4   Apple      MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz
# 5    Acer         Aspire 3   Notebook    15.6     AMD A9-Series 9420 3GHz
# 6   Apple      MacBook Pro  Ultrabook    15.4        Intel Core i7 2.2GHz
# 7   Apple      Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz
# 8    Asus  ZenBook UX430UN  Ultrabook    14.0  Intel Core i7 8550U 1.8GHz
# 9    Acer          Swift 3  Ultrabook    14.0  Intel Core i5 8250U 1.6GHz
#
#     Ram                           Gpu       OpSys  Weight  Price_euros  \
# 0   8GB  Intel Iris Plus Graphics 640       macOS    1.37      1339.69
# 1   8GB        Intel HD Graphics 6000       macOS    1.34       898.94
# 2   8GB         Intel HD Graphics 620       No OS    1.86       575.00
# 3  16GB            AMD Radeon Pro 455       macOS    1.83      2537.45
# 4   8GB  Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# 5   4GB                 AMD Radeon R5  Windows 10    2.10       400.00
# 6  16GB       Intel Iris Pro Graphics    Mac OS X    2.04      2139.97
# 7   8GB        Intel HD Graphics 6000       macOS    1.34      1158.70
# 8  16GB          Nvidia GeForce MX150  Windows 10    1.30      1495.00
# 9   8GB        Intel UHD Graphics 620  Windows 10    1.60       770.00
#
#   Cpu_Company  Memory_Amount   Memory_Type
# 0       Intel            128           SSD
# 1       Intel            128  FlashStorage
# 2       Intel            256           SSD
# 3       Intel            512           SSD
# 4       Intel            256           SSD
# 5         AMD            500           HDD
# 6       Intel            256  FlashStorage
# 7       Intel            256  FlashStorage
# 8       Intel            512           SSD
# 9       Intel            256           SSD

# %%
pd.set_option("max_colwidth", 10)

# %%
df
# Out:
#      Company    Product   TypeName  Inches        Cpu   Ram        Gpu  \
# 0      Apple  MacBoo...  Ultrabook    13.3  Intel ...   8GB  Intel ...
# 1      Apple  Macboo...  Ultrabook    13.3  Intel ...   8GB  Intel ...
# 2         HP     250 G6   Notebook    15.6  Intel ...   8GB  Intel ...
# 3      Apple  MacBoo...  Ultrabook    15.4  Intel ...  16GB  AMD Ra...
# 4      Apple  MacBoo...  Ultrabook    13.3  Intel ...   8GB  Intel ...
# ...      ...        ...        ...     ...        ...   ...        ...
# 1298  Lenovo  Yoga 5...  2 in 1...    14.0  Intel ...   4GB  Intel ...
# 1299  Lenovo  Yoga 9...  2 in 1...    13.3  Intel ...  16GB  Intel ...
# 1300  Lenovo  IdeaPa...   Notebook    14.0  Intel ...   2GB  Intel ...
# 1301      HP  15-AC1...   Notebook    15.6  Intel ...   6GB  AMD Ra...
# 1302    Asus  X553SA...   Notebook    15.6  Intel ...   4GB  Intel ...
#
#           OpSys  Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type
# 0         macOS    1.37    1339.69        Intel         128            SSD
# 1         macOS    1.34     898.94        Intel         128      FlashS...
# 2         No OS    1.86     575.00        Intel         256            SSD
# 3         macOS    1.83    2537.45        Intel         512            SSD
# 4         macOS    1.37    1803.60        Intel         256            SSD
# ...         ...     ...        ...          ...         ...            ...
# 1298  Window...    1.80     638.00        Intel         128            SSD
# 1299  Window...    1.30    1499.00        Intel         512            SSD
# 1300  Window...    1.50     229.00        Intel          64      FlashS...
# 1301  Window...    2.19     764.00        Intel        1024            HDD
# 1302  Window...    2.20     369.00        Intel         500            HDD
#
# [1303 rows x 13 columns]

# %%
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# compute.use_numba : bool
#     Use the numba engine option for select operations if it is installed,
#     the default is False
#     Valid values: False,True
#     [default: False] [currently: False]
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller than the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# display.date_dayfirst : boolean
#     When True, prints and parses dates with the day first, eg 20/01/2005
#     [default: False] [currently: False]
# display.date_yearfirst : boolean
#     When True, prints and parses dates with the year first, eg 2005/01/20
#     [default: False] [currently: False]
# display.encoding : str/unicode
#     Defaults to the detected encoding of the console.
#     Specifies the encoding to be used for strings returned by to_string,
#     these are generally strings meant to be displayed on the console.
#     [default: UTF-8] [currently: UTF-8]
# display.expand_frame_repr : boolean
#     Whether to print out the full DataFrame repr for wide DataFrames across
#     multiple lines, `max_columns` is still respected, but the output will
#     wrap-around across multiple "pages" if its width exceeds `display.width`.
#     [default: True] [currently: True]
# display.float_format : callable
#     The callable should accept a floating point number and return
#     a string with the desired format of the number. This is used
#     in some places like SeriesFormatter.
#     See formats.format.EngFormatter for an example.
#     [default: None] [currently: None]
# display.html.border : int
#     A ``border=value`` attribute is inserted in the ``<table>`` tag
#     for the DataFrame HTML repr.
#     [default: 1] [currently: 1]
# display.html.table_schema : boolean
#     Whether to publish a Table Schema representation for frontends
#     that support it.
#     (default: False)
#     [default: False] [currently: False]
# display.html.use_mathjax : boolean
#     When True, Jupyter notebook will process table contents using MathJax,
#     rendering mathematical expressions enclosed by the dollar symbol.
#     (default: True)
#     [default: True] [currently: True]
# display.large_repr : 'truncate'/'info'
#     For DataFrames exceeding max_rows/max_cols, the repr (and HTML repr) can
#     show a truncated table, or switch to the view from
#     df.info() (the behaviour in earlier versions of pandas).
#     [default: truncate] [currently: truncate]
# display.max_categories : int
#     This sets the maximum number of categories pandas should output when
#     printing out a `Categorical` or a Series of dtype "category".
#     [default: 8] [currently: 8]
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 or None and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection and defaults to 20.
#     [default: 20] [currently: 20]
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 10]
# display.max_dir_items : int
#     The number of items that will be added to `dir(...)`. 'None' value means
#     unlimited. Because dir is cached, changing this option will not immediately
#     affect already existing dataframes until a column is deleted or added.
#
#     This is for instance used to suggest columns from a dataframe to tab
#     completion.
#     [default: 100] [currently: 100]
# display.max_info_columns : int
#     max_info_columns is used in DataFrame.info method to decide if
#     per column information will be printed.
#     [default: 100] [currently: 100]
# display.max_info_rows : int
#     df.info() will usually show null-counts for each column.
#     For large frames this can be quite slow. max_info_rows and max_info_cols
#     limit this null check only to frames with smaller dimensions than
#     specified.
#     [default: 1690785] [currently: 1690785]
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 100]
# display.max_seq_items : int or None
#     When pretty-printing a long sequence, no more then `max_seq_items`
#     will be printed. If items are omitted, they will be denoted by the
#     addition of "..." to the resulting string.
#
#     If set to None, the number of items to be printed is unlimited.
#     [default: 100] [currently: 100]
# display.memory_usage : bool, string or None
#     This specifies if the memory usage of a DataFrame should be displayed when
#     df.info() is called. Valid values True,False,'deep'
#     [default: True] [currently: True]
# display.min_rows : int
#     The numbers of rows to show in a truncated view (when `max_rows` is
#     exceeded). Ignored when `max_rows` is set to None or 0. When set to
#     None, follows the value of `max_rows`.
#     [default: 10] [currently: 10]
# display.multi_sparse : boolean
#     "sparsify" MultiIndex display (don't display repeated
#     elements in outer levels within groups)
#     [default: True] [currently: True]
# display.notebook_repr_html : boolean
#     When True, IPython notebook will use html representation for
#     pandas objects (if it is available).
#     [default: True] [currently: True]
# display.pprint_nest_depth : int
#     Controls the number of nested levels to process when pretty-printing
#     [default: 3] [currently: 3]
# display.precision : int
#     Floating point output precision in terms of number of places after the
#     decimal, for regular formatting as well as scientific notation. Similar
#     to ``precision`` in :meth:`numpy.set_printoptions`.
#     [default: 6] [currently: 6]
# display.show_dimensions : boolean or 'truncate'
#     Whether to print out dimensions at the end of DataFrame repr.
#     If 'truncate' is specified, only print out the dimensions if the
#     frame is truncated (e.g. not display all rows and/or columns)
#     [default: truncate] [currently: truncate]
# display.unicode.ambiguous_as_wide : boolean
#     Whether to use the Unicode East Asian Width to calculate the display text
#     width.
#     Enabling this may affect to the performance (default: False)
#     [default: False] [currently: False]
# display.unicode.east_asian_width : boolean
#     Whether to use the Unicode East Asian Width to calculate the display text
#     width.
#     Enabling this may affect to the performance (default: False)
#     [default: False] [currently: False]
# display.width : int
#     Width of the display in characters. In case python/IPython is running in
#     a terminal this can be set to None and pandas will correctly auto-detect
#     the width.
#     Note that the IPython notebook, IPython qtconsole, or IDLE do not run in a
#     terminal and hence it is not possible to correctly detect the width.
#     [default: 80] [currently: 80]
# future.infer_string Whether to infer sequence of str objects as pyarrow string dtype, which will be the default in pandas 3.0 (at which point this option will be deprecated).
#     [default: False] [currently: False]
# future.no_silent_downcasting Whether to opt-in to the future behavior which will *not* silently downcast results from Series and DataFrame `where`, `mask`, and `clip` methods. Silent downcasting will be removed in pandas 3.0 (at which point this option will be deprecated).
#     [default: False] [currently: False]
# io.excel.ods.reader : string
#     The default Excel reader engine for 'ods' files. Available options:
#     auto, odf, calamine.
#     [default: auto] [currently: auto]
# io.excel.ods.writer : string
#     The default Excel writer engine for 'ods' files. Available options:
#     auto, odf.
#     [default: auto] [currently: auto]
# io.excel.xls.reader : string
#     The default Excel reader engine for 'xls' files. Available options:
#     auto, xlrd, calamine.
#     [default: auto] [currently: auto]
# io.excel.xlsb.reader : string
#     The default Excel reader engine for 'xlsb' files. Available options:
#     auto, pyxlsb, calamine.
#     [default: auto] [currently: auto]
# io.excel.xlsm.reader : string
#     The default Excel reader engine for 'xlsm' files. Available options:
#     auto, xlrd, openpyxl, calamine.
#     [default: auto] [currently: auto]
# io.excel.xlsm.writer : string
#     The default Excel writer engine for 'xlsm' files. Available options:
#     auto, openpyxl.
#     [default: auto] [currently: auto]
# io.excel.xlsx.reader : string
#     The default Excel reader engine for 'xlsx' files. Available options:
#     auto, xlrd, openpyxl, calamine.
#     [default: auto] [currently: auto]
# io.excel.xlsx.writer : string
#     The default Excel writer engine for 'xlsx' files. Available options:
#     auto, openpyxl, xlsxwriter.
#     [default: auto] [currently: auto]
# io.hdf.default_format : format
#     default format writing format, if None, then
#     put will default to 'fixed' and append will default to 'table'
#     [default: None] [currently: None]
# io.hdf.dropna_table : boolean
#     drop ALL nan rows when appending to a table
#     [default: False] [currently: False]
# io.parquet.engine : string
#     The default parquet reader/writer engine. Available options:
#     'auto', 'pyarrow', 'fastparquet', the default is 'auto'
#     [default: auto] [currently: auto]
# io.sql.engine : string
#     The default sql reader/writer engine. Available options:
#     'auto', 'sqlalchemy', the default is 'auto'
#     [default: auto] [currently: auto]
# mode.chained_assignment : string
#     Raise an exception, warn, or no action if trying to use chained assignment,
#     The default is warn
#     [default: warn] [currently: warn]
# mode.copy_on_write : bool
#     Use new copy-view behaviour using Copy-on-Write. Defaults to False,
#     unless overridden by the 'PANDAS_COPY_ON_WRITE' environment variable
#     (if set to "1" for True, needs to be set before pandas is imported).
#     [default: False] [currently: False]
# mode.data_manager : string
#     Internal data manager type; can be "block" or "array". Defaults to "block",
#     unless overridden by the 'PANDAS_DATA_MANAGER' environment variable (needs
#     to be set before pandas is imported).
#     [default: block] [currently: block]
#     (Deprecated, use `` instead.)
# mode.sim_interactive : boolean
#     Whether to simulate interactive mode for purposes of testing
#     [default: False] [currently: False]
# mode.string_storage : string
#     The default storage for StringDtype. This option is ignored if
#     ``future.infer_string`` is set to True.
#     [default: python] [currently: python]
# mode.use_inf_as_na : boolean
#     True means treat None, NaN, INF, -INF as NA (old way),
#     False means None and NaN are null, but INF, -INF are not NA
#     (new way).
#
#     This option is deprecated in pandas 2.1.0 and will be removed in 3.0.
#     [default: False] [currently: False]
#     (Deprecated, use `` instead.)
# plotting.backend : str
#     The plotting backend to use. The default value is "matplotlib", the
#     backend provided with pandas. Other backends can be specified by
#     providing the name of the module that implements the backend.
#     [default: matplotlib] [currently: matplotlib]
# plotting.matplotlib.register_converters : bool or 'auto'.
#     Whether to register converters with matplotlib's units registry for
#     dates, times, datetimes, and Periods. Toggling to False will remove
#     the converters, restoring any converters that pandas overwrote.
#     [default: auto] [currently: auto]
# styler.format.decimal : str
#     The character representation for the decimal separator for floats and complex.
#     [default: .] [currently: .]
# styler.format.escape : str, optional
#     Whether to escape certain characters according to the given context; html or latex.
#     [default: None] [currently: None]
# styler.format.formatter : str, callable, dict, optional
#     A formatter object to be used as default within ``Styler.format``.
#     [default: None] [currently: None]
# styler.format.na_rep : str, optional
#     The string representation for values identified as missing.
#     [default: None] [currently: None]
# styler.format.precision : int
#     The precision for floats and complex numbers.
#     [default: 6] [currently: 6]
# styler.format.thousands : str, optional
#     The character representation for thousands separator for floats, int and complex.
#     [default: None] [currently: None]
# styler.html.mathjax : bool
#     If False will render special CSS classes to table attributes that indicate Mathjax
#     will not be used in Jupyter Notebook.
#     [default: True] [currently: True]
# styler.latex.environment : str
#     The environment to replace ``\begin{table}``. If "longtable" is used results
#     in a specific longtable environment format.
#     [default: None] [currently: None]
# styler.latex.hrules : bool
#     Whether to add horizontal rules on top and bottom and below the headers.
#     [default: False] [currently: False]
# styler.latex.multicol_align : {"r", "c", "l", "naive-l", "naive-r"}
#     The specifier for horizontal alignment of sparsified LaTeX multicolumns. Pipe
#     decorators can also be added to non-naive values to draw vertical
#     rules, e.g. "\|r" will draw a rule on the left side of right aligned merged cells.
#     [default: r] [currently: r]
# styler.latex.multirow_align : {"c", "t", "b"}
#     The specifier for vertical alignment of sparsified LaTeX multirows.
#     [default: c] [currently: c]
# styler.render.encoding : str
#     The encoding used for output HTML and LaTeX files.
#     [default: utf-8] [currently: utf-8]
# styler.render.max_columns : int, optional
#     The maximum number of columns that will be rendered. May still be reduced to
#     satisfy ``max_elements``, which takes precedence.
#     [default: None] [currently: None]
# styler.render.max_elements : int
#     The maximum number of data-cell (<td>) elements that will be rendered before
#     trimming will occur over columns, rows or both if needed.
#     [default: 262144] [currently: 262144]
# styler.render.max_rows : int, optional
#     The maximum number of rows that will be rendered. May still be reduced to
#     satisfy ``max_elements``, which takes precedence.
#     [default: None] [currently: None]
# styler.render.repr : str
#     Determine which output to use in Jupyter Notebook in {"html", "latex"}.
#     [default: html] [currently: html]
# styler.sparse.columns : bool
#     Whether to sparsify the display of hierarchical columns. Setting to False will
#     display each explicit level element in a hierarchical key for each column.
#     [default: True] [currently: True]
# styler.sparse.index : bool
#     Whether to sparsify the display of a hierarchical index. Setting to False will
#     display each explicit level element in a hierarchical key for each row.
#     [default: True] [currently: True]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   Product        1303 non-null   object
#  2   TypeName       1303 non-null   object
#  3   Inches         1303 non-null   float64
#  4   Cpu            1303 non-null   object
#  5   Ram            1303 non-null   object
#  6   Gpu            1303 non-null   object
#  7   OpSys          1303 non-null   object
#  8   Weight         1303 non-null   float64
#  9   Price_euros    1303 non-null   float64
#  10  Cpu_Company    1303 non-null   object
#  11  Memory_Amount  1303 non-null   int64
#  12  Memory_Type    1303 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 132.5+ KB

# %%
display_settings = {
    'max_columns': 10,
    'colheader_justify': 'left',
    'large_repr': 'info'
}

for op, value in display_settings.items():
    pd.set_option(f"display.{op}", value)

# %%
# display_settings.items()

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   Product        1303 non-null   object
#  2   TypeName       1303 non-null   object
#  3   Inches         1303 non-null   float64
#  4   Cpu            1303 non-null   object
#  5   Ram            1303 non-null   object
#  6   Gpu            1303 non-null   object
#  7   OpSys          1303 non-null   object
#  8   Weight         1303 non-null   float64
#  9   Price_euros    1303 non-null   float64
#  10  Cpu_Company    1303 non-null   object
#  11  Memory_Amount  1303 non-null   int64
#  12  Memory_Type    1303 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 132.5+ KB

# %%
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        5 non-null      object
#  1   Product        5 non-null      object
#  2   TypeName       5 non-null      object
#  3   Inches         5 non-null      float64
#  4   Cpu            5 non-null      object
#  5   Ram            5 non-null      object
#  6   Gpu            5 non-null      object
#  7   OpSys          5 non-null      object
#  8   Weight         5 non-null      float64
#  9   Price_euros    5 non-null      float64
#  10  Cpu_Company    5 non-null      object
#  11  Memory_Amount  5 non-null      int64
#  12  Memory_Type    5 non-null      object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 652.0+ bytes

# %%
pd.reset_option('large_repr')

# %%
df
# Out:
#      Company Product    TypeName    Inches Cpu         ... Weight Price_euros  \
# 0      Apple  MacBoo...  Ultrabook  13.3    Intel ...  ...  1.37   1339.69
# 1      Apple  Macboo...  Ultrabook  13.3    Intel ...  ...  1.34    898.94
# 2         HP     250 G6   Notebook  15.6    Intel ...  ...  1.86    575.00
# 3      Apple  MacBoo...  Ultrabook  15.4    Intel ...  ...  1.83   2537.45
# 4      Apple  MacBoo...  Ultrabook  13.3    Intel ...  ...  1.37   1803.60
# ...      ...        ...        ...     ...        ...  ...    ...        ...
# 1298  Lenovo  Yoga 5...  2 in 1...  14.0    Intel ...  ...  1.80    638.00
# 1299  Lenovo  Yoga 9...  2 in 1...  13.3    Intel ...  ...  1.30   1499.00
# 1300  Lenovo  IdeaPa...   Notebook  14.0    Intel ...  ...  1.50    229.00
# 1301      HP  15-AC1...   Notebook  15.6    Intel ...  ...  2.19    764.00
# 1302    Asus  X553SA...   Notebook  15.6    Intel ...  ...  2.20    369.00
#
#      Cpu_Company  Memory_Amount  Memory_Type
# 0     Intel        128                 SSD
# 1     Intel        128           FlashS...
# 2     Intel        256                 SSD
# 3     Intel        512                 SSD
# 4     Intel        256                 SSD
# ...         ...         ...            ...
# 1298  Intel        128                 SSD
# 1299  Intel        512                 SSD
# 1300  Intel         64           FlashS...
# 1301  Intel       1024                 HDD
# 1302  Intel        500                 HDD
#
# [1303 rows x 13 columns]

# %%
pd.set_option("display.max_info_columns", 200)

# %%
# # pandas
# pd.set_option("display.max_columns", None)      # показывать все столбцы
# pd.set_option("display.max_rows", 100)          # сколько строк максимум показывать
# pd.set_option("display.width", 1200)            # ширина вывода
# pd.set_option("display.max_colwidth", 200)      # ширина текста в ячейке
# pd.set_option("display.float_format", "{:.2f}".format)  # формат float

# # matplotlib
# plt.rcParams["figure.figsize"] = (8, 5)         # размер графиков по умолчанию
# plt.rcParams["figure.dpi"] = 120                # качество
# plt.rcParams["font.size"] = 11                  # размер шрифта
# plt.rcParams["axes.titlesize"] = 13             # заголовок графика
# plt.rcParams["axes.labelsize"] = 11             # подписи осей
# plt.rcParams["xtick.labelsize"] = 10
# plt.rcParams["ytick.labelsize"] = 10
# plt.rcParams["legend.fontsize"] = 10

# # стиль графиков
# plt.style.use("default")

# %% [markdown]
# ### Warnings

# %%
import warnings
warnings.warn("Это предупреждение!")
# Out:
# /tmp/ipykernel_279/2856871940.py:2: UserWarning: Это предупреждение!
#   warnings.warn("Это предупреждение!")

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Настройка темы ноутбука
# [ссылка](https://www.geeksforgeeks.org/how-to-change-the-theme-in-jupyter-notebook/)

# %%
# !pip install jupyterthemes

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\Dasha\.jupyter\custom &
# C:\Users\Dasha\AppData\Roaming\jupyter\nbextensions

# %% [markdown]
# ### Настройка вывода таблицы

# %%
df = pd.DataFrame(np.random.normal(size=(6,6)), columns=[x for x in "ABCDEF"])
df
# Out:
#    A         B         C         D         E         F
# 0  0.203441 -1.579559  0.076420  2.270737  1.459605  0.576294
# 1 -0.493965 -0.950349  1.612466 -0.232065  0.158511 -1.676749
# 2 -0.295816 -0.367696 -0.860680  2.023045 -1.187149 -0.417573
# 3  0.675255  1.599868  0.171656 -0.878916  0.836571 -0.137732
# 4 -0.458623 -0.337565 -1.120269  0.041328 -1.401812 -0.610949
# 5  0.261927 -0.006816  0.230570 -0.587268 -0.361588  1.475556

# %%
def neg_red(x):
    return f"color: {'red' if x < 0 else 'green'}"

# df.style.applymap(neg_red)

df.style.applymap(lambda x: f"color: {'red' if x < 0 else 'black'}")
# Out:
# /tmp/ipykernel_279/3269217224.py:6: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df.style.applymap(lambda x: f"color: {'red' if x < 0 else 'black'}")
# <style type="text/css">
# #T_7b622_row0_col0, #T_7b622_row0_col2, #T_7b622_row0_col3, #T_7b622_row0_col4, #T_7b622_row0_col5, #T_7b622_row1_col2, #T_7b622_row1_col4, #T_7b622_row2_col3, #T_7b622_row3_col0, #T_7b622_row3_col1, #T_7b622_row3_col2, #T_7b622_row3_col4, #T_7b622_row4_col3, #T_7b622_row5_col0, #T_7b622_row5_col2, #T_7b622_row5_col5 {
#   color: black;
# }
# #T_7b622_row0_col1, #T_7b622_row1_col0, #T_7b622_row1_col1, #T_7b622_row1_col3, #T_7b622_row1_col5, #T_7b622_row2_col0, #T_7b622_row2_col1, #T_7b622_row2_col2, #T_7b622_row2_col4, #T_7b622_row2_col5, #T_7b622_row3_col3, #T_7b622_row3_col5, #T_7b622_row4_col0, #T_7b622_row4_col1, #T_7b622_row4_col2, #T_7b622_row4_col4, #T_7b622_row4_col5, #T_7b622_row5_col1, #T_7b622_row5_col3, #T_7b622_row5_col4 {
#   color: red;
# }
# </style>
# <table id="T_7b622" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b622_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7b622_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_7b622_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_7b622_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_7b622_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_7b622_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b622_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b622_row0_col0" class="data row0 col0" >0.203441</td>
#       <td id="T_7b622_row0_col1" class="data row0 col1" >-1.579559</td>
#       <td id="T_7b622_row0_col2" class="data row0 col2" >0.076420</td>
#       <td id="T_7b622_row0_col3" class="data row0 col3" >2.270737</td>
#       <td id="T_7b622_row0_col4" class="data row0 col4" >1.459605</td>
#       <td id="T_7b622_row0_col5" class="data row0 col5" >0.576294</td>
#     </tr>
#     <tr>
#       <th id="T_7b622_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b622_row1_col0" class="data row1 col0" >-0.493965</td>
#       <td id="T_7b622_row1_col1" class="data row1 col1" >-0.950349</td>
#       <td id="T_7b622_row1_col2" class="data row1 col2" >1.612466</td>
#       <td id="T_7b622_row1_col3" class="data row1 col3" >-0.232065</td>
#       <td id="T_7b622_row1_col4" class="data row1 col4" >0.158511</td>
#       <td id="T_7b622_row1_col5" class="data row1 col5" >-1.676749</td>
#     </tr>
#     <tr>
#       <th id="T_7b622_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b622_row2_col0" class="data row2 col0" >-0.295816</td>
#       <td id="T_7b622_row2_col1" class="data row2 col1" >-0.367696</td>
#       <td id="T_7b622_row2_col2" class="data row2 col2" >-0.860680</td>
#       <td id="T_7b622_row2_col3" class="data row2 col3" >2.023045</td>
#       <td id="T_7b622_row2_col4" class="data row2 col4" >-1.187149</td>
#       <td id="T_7b622_row2_col5" class="data row2 col5" >-0.417573</td>
#     </tr>
#     <tr>
#       <th id="T_7b622_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b622_row3_col0" class="data row3 col0" >0.675255</td>
#       <td id="T_7b622_row3_col1" class="data row3 col1" >1.599868</td>
#       <td id="T_7b622_row3_col2" class="data row3 col2" >0.171656</td>
#       <td id="T_7b622_row3_col3" class="data row3 col3" >-0.878916</td>
#       <td id="T_7b622_row3_col4" class="data row3 col4" >0.836571</td>
#       <td id="T_7b622_row3_col5" class="data row3 col5" >-0.137732</td>
#     </tr>
#     <tr>
#       <th id="T_7b622_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b622_row4_col0" class="data row4 col0" >-0.458623</td>
#       <td id="T_7b622_row4_col1" class="data row4 col1" >-0.337565</td>
#       <td id="T_7b622_row4_col2" class="data row4 col2" >-1.120269</td>
#       <td id="T_7b622_row4_col3" class="data row4 col3" >0.041328</td>
#       <td id="T_7b622_row4_col4" class="data row4 col4" >-1.401812</td>
#       <td id="T_7b622_row4_col5" class="data row4 col5" >-0.610949</td>
#     </tr>
#     <tr>
#       <th id="T_7b622_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7b622_row5_col0" class="data row5 col0" >0.261927</td>
#       <td id="T_7b622_row5_col1" class="data row5 col1" >-0.006816</td>
#       <td id="T_7b622_row5_col2" class="data row5 col2" >0.230570</td>
#       <td id="T_7b622_row5_col3" class="data row5 col3" >-0.587268</td>
#       <td id="T_7b622_row5_col4" class="data row5 col4" >-0.361588</td>
#       <td id="T_7b622_row5_col5" class="data row5 col5" >1.475556</td>
#     </tr>
#   </tbody>
# </table>

# %%
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (xs == m).replace(color)
    return is_max

# %%
df.style.apply(gold_max, axis=None)
# Out:
# <style type="text/css">
# #T_15f1f_row0_col3 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_15f1f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15f1f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_15f1f_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_15f1f_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_15f1f_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_15f1f_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_15f1f_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15f1f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15f1f_row0_col0" class="data row0 col0" >0.203441</td>
#       <td id="T_15f1f_row0_col1" class="data row0 col1" >-1.579559</td>
#       <td id="T_15f1f_row0_col2" class="data row0 col2" >0.076420</td>
#       <td id="T_15f1f_row0_col3" class="data row0 col3" >2.270737</td>
#       <td id="T_15f1f_row0_col4" class="data row0 col4" >1.459605</td>
#       <td id="T_15f1f_row0_col5" class="data row0 col5" >0.576294</td>
#     </tr>
#     <tr>
#       <th id="T_15f1f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15f1f_row1_col0" class="data row1 col0" >-0.493965</td>
#       <td id="T_15f1f_row1_col1" class="data row1 col1" >-0.950349</td>
#       <td id="T_15f1f_row1_col2" class="data row1 col2" >1.612466</td>
#       <td id="T_15f1f_row1_col3" class="data row1 col3" >-0.232065</td>
#       <td id="T_15f1f_row1_col4" class="data row1 col4" >0.158511</td>
#       <td id="T_15f1f_row1_col5" class="data row1 col5" >-1.676749</td>
#     </tr>
#     <tr>
#       <th id="T_15f1f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_15f1f_row2_col0" class="data row2 col0" >-0.295816</td>
#       <td id="T_15f1f_row2_col1" class="data row2 col1" >-0.367696</td>
#       <td id="T_15f1f_row2_col2" class="data row2 col2" >-0.860680</td>
#       <td id="T_15f1f_row2_col3" class="data row2 col3" >2.023045</td>
#       <td id="T_15f1f_row2_col4" class="data row2 col4" >-1.187149</td>
#       <td id="T_15f1f_row2_col5" class="data row2 col5" >-0.417573</td>
#     </tr>
#     <tr>
#       <th id="T_15f1f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_15f1f_row3_col0" class="data row3 col0" >0.675255</td>
#       <td id="T_15f1f_row3_col1" class="data row3 col1" >1.599868</td>
#       <td id="T_15f1f_row3_col2" class="data row3 col2" >0.171656</td>
#       <td id="T_15f1f_row3_col3" class="data row3 col3" >-0.878916</td>
#       <td id="T_15f1f_row3_col4" class="data row3 col4" >0.836571</td>
#       <td id="T_15f1f_row3_col5" class="data row3 col5" >-0.137732</td>
#     </tr>
#     <tr>
#       <th id="T_15f1f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_15f1f_row4_col0" class="data row4 col0" >-0.458623</td>
#       <td id="T_15f1f_row4_col1" class="data row4 col1" >-0.337565</td>
#       <td id="T_15f1f_row4_col2" class="data row4 col2" >-1.120269</td>
#       <td id="T_15f1f_row4_col3" class="data row4 col3" >0.041328</td>
#       <td id="T_15f1f_row4_col4" class="data row4 col4" >-1.401812</td>
#       <td id="T_15f1f_row4_col5" class="data row4 col5" >-0.610949</td>
#     </tr>
#     <tr>
#       <th id="T_15f1f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_15f1f_row5_col0" class="data row5 col0" >0.261927</td>
#       <td id="T_15f1f_row5_col1" class="data row5 col1" >-0.006816</td>
#       <td id="T_15f1f_row5_col2" class="data row5 col2" >0.230570</td>
#       <td id="T_15f1f_row5_col3" class="data row5 col3" >-0.587268</td>
#       <td id="T_15f1f_row5_col4" class="data row5 col4" >-0.361588</td>
#       <td id="T_15f1f_row5_col5" class="data row5 col5" >1.475556</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.background_gradient(cmap="magma")
# Out:
# <style type="text/css">
# #T_26d0e_row0_col0 {
#   background-color: #dc4869;
#   color: #f1f1f1;
# }
# #T_26d0e_row0_col1, #T_26d0e_row1_col0, #T_26d0e_row1_col5, #T_26d0e_row3_col3, #T_26d0e_row4_col2, #T_26d0e_row4_col4 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_26d0e_row0_col2 {
#   background-color: #9c2e7f;
#   color: #f1f1f1;
# }
# #T_26d0e_row0_col3, #T_26d0e_row0_col4, #T_26d0e_row1_col2, #T_26d0e_row3_col0, #T_26d0e_row3_col1, #T_26d0e_row5_col5 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_26d0e_row0_col5 {
#   background-color: #f8765c;
#   color: #f1f1f1;
# }
# #T_26d0e_row1_col1 {
#   background-color: #390f6e;
#   color: #f1f1f1;
# }
# #T_26d0e_row1_col3 {
#   background-color: #3d0f71;
#   color: #f1f1f1;
# }
# #T_26d0e_row1_col4 {
#   background-color: #c83e73;
#   color: #f1f1f1;
# }
# #T_26d0e_row2_col0 {
#   background-color: #2d1161;
#   color: #f1f1f1;
# }
# #T_26d0e_row2_col1 {
#   background-color: #842681;
#   color: #f1f1f1;
# }
# #T_26d0e_row2_col2 {
#   background-color: #130d34;
#   color: #f1f1f1;
# }
# #T_26d0e_row2_col3 {
#   background-color: #fed89a;
#   color: #000000;
# }
# #T_26d0e_row2_col4 {
#   background-color: #0d0a29;
#   color: #f1f1f1;
# }
# #T_26d0e_row2_col5 {
#   background-color: #8c2981;
#   color: #f1f1f1;
# }
# #T_26d0e_row3_col2 {
#   background-color: #ab337c;
#   color: #f1f1f1;
# }
# #T_26d0e_row3_col4 {
#   background-color: #fd9869;
#   color: #000000;
# }
# #T_26d0e_row3_col5 {
#   background-color: #b0357b;
#   color: #f1f1f1;
# }
# #T_26d0e_row4_col0 {
#   background-color: #03030f;
#   color: #f1f1f1;
# }
# #T_26d0e_row4_col1 {
#   background-color: #892881;
#   color: #f1f1f1;
# }
# #T_26d0e_row4_col3 {
#   background-color: #601880;
#   color: #f1f1f1;
# }
# #T_26d0e_row4_col5 {
#   background-color: #732081;
#   color: #f1f1f1;
# }
# #T_26d0e_row5_col0 {
#   background-color: #ec5860;
#   color: #f1f1f1;
# }
# #T_26d0e_row5_col1, #T_26d0e_row5_col2 {
#   background-color: #b3367a;
#   color: #f1f1f1;
# }
# #T_26d0e_row5_col3 {
#   background-color: #120d31;
#   color: #f1f1f1;
# }
# #T_26d0e_row5_col4 {
#   background-color: #7e2482;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26d0e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26d0e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_26d0e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_26d0e_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_26d0e_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_26d0e_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_26d0e_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26d0e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26d0e_row0_col0" class="data row0 col0" >0.203441</td>
#       <td id="T_26d0e_row0_col1" class="data row0 col1" >-1.579559</td>
#       <td id="T_26d0e_row0_col2" class="data row0 col2" >0.076420</td>
#       <td id="T_26d0e_row0_col3" class="data row0 col3" >2.270737</td>
#       <td id="T_26d0e_row0_col4" class="data row0 col4" >1.459605</td>
#       <td id="T_26d0e_row0_col5" class="data row0 col5" >0.576294</td>
#     </tr>
#     <tr>
#       <th id="T_26d0e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26d0e_row1_col0" class="data row1 col0" >-0.493965</td>
#       <td id="T_26d0e_row1_col1" class="data row1 col1" >-0.950349</td>
#       <td id="T_26d0e_row1_col2" class="data row1 col2" >1.612466</td>
#       <td id="T_26d0e_row1_col3" class="data row1 col3" >-0.232065</td>
#       <td id="T_26d0e_row1_col4" class="data row1 col4" >0.158511</td>
#       <td id="T_26d0e_row1_col5" class="data row1 col5" >-1.676749</td>
#     </tr>
#     <tr>
#       <th id="T_26d0e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26d0e_row2_col0" class="data row2 col0" >-0.295816</td>
#       <td id="T_26d0e_row2_col1" class="data row2 col1" >-0.367696</td>
#       <td id="T_26d0e_row2_col2" class="data row2 col2" >-0.860680</td>
#       <td id="T_26d0e_row2_col3" class="data row2 col3" >2.023045</td>
#       <td id="T_26d0e_row2_col4" class="data row2 col4" >-1.187149</td>
#       <td id="T_26d0e_row2_col5" class="data row2 col5" >-0.417573</td>
#     </tr>
#     <tr>
#       <th id="T_26d0e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26d0e_row3_col0" class="data row3 col0" >0.675255</td>
#       <td id="T_26d0e_row3_col1" class="data row3 col1" >1.599868</td>
#       <td id="T_26d0e_row3_col2" class="data row3 col2" >0.171656</td>
#       <td id="T_26d0e_row3_col3" class="data row3 col3" >-0.878916</td>
#       <td id="T_26d0e_row3_col4" class="data row3 col4" >0.836571</td>
#       <td id="T_26d0e_row3_col5" class="data row3 col5" >-0.137732</td>
#     </tr>
#     <tr>
#       <th id="T_26d0e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_26d0e_row4_col0" class="data row4 col0" >-0.458623</td>
#       <td id="T_26d0e_row4_col1" class="data row4 col1" >-0.337565</td>
#       <td id="T_26d0e_row4_col2" class="data row4 col2" >-1.120269</td>
#       <td id="T_26d0e_row4_col3" class="data row4 col3" >0.041328</td>
#       <td id="T_26d0e_row4_col4" class="data row4 col4" >-1.401812</td>
#       <td id="T_26d0e_row4_col5" class="data row4 col5" >-0.610949</td>
#     </tr>
#     <tr>
#       <th id="T_26d0e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_26d0e_row5_col0" class="data row5 col0" >0.261927</td>
#       <td id="T_26d0e_row5_col1" class="data row5 col1" >-0.006816</td>
#       <td id="T_26d0e_row5_col2" class="data row5 col2" >0.230570</td>
#       <td id="T_26d0e_row5_col3" class="data row5 col3" >-0.587268</td>
#       <td id="T_26d0e_row5_col4" class="data row5 col4" >-0.361588</td>
#       <td id="T_26d0e_row5_col5" class="data row5 col5" >1.475556</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.abs().style.bar(align="left", width=90)
# Out:
# <style type="text/css">
# #T_fe7a9_row0_col0, #T_fe7a9_row0_col2, #T_fe7a9_row1_col4, #T_fe7a9_row3_col5, #T_fe7a9_row4_col3, #T_fe7a9_row5_col1 {
#   width: 10em;
# }
# #T_fe7a9_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.9%, transparent 88.9%);
# }
# #T_fe7a9_row0_col3, #T_fe7a9_row0_col4, #T_fe7a9_row1_col2, #T_fe7a9_row1_col5, #T_fe7a9_row3_col0, #T_fe7a9_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.0%, transparent 90.0%);
# }
# #T_fe7a9_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.6%, transparent 25.6%);
# }
# #T_fe7a9_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 55.4%, transparent 55.4%);
# }
# #T_fe7a9_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_fe7a9_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.7%, transparent 7.7%);
# }
# #T_fe7a9_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.6%, transparent 17.6%);
# }
# #T_fe7a9_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.4%, transparent 20.4%);
# }
# #T_fe7a9_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.0%, transparent 46.0%);
# }
# #T_fe7a9_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.0%, transparent 80.0%);
# }
# #T_fe7a9_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.2%, transparent 71.2%);
# }
# #T_fe7a9_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.4%, transparent 16.4%);
# }
# #T_fe7a9_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.6%, transparent 5.6%);
# }
# #T_fe7a9_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.8%, transparent 33.8%);
# }
# #T_fe7a9_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.9%, transparent 46.9%);
# }
# #T_fe7a9_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.7%, transparent 48.7%);
# }
# #T_fe7a9_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.7%, transparent 18.7%);
# }
# #T_fe7a9_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 61.2%, transparent 61.2%);
# }
# #T_fe7a9_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.0%, transparent 86.0%);
# }
# #T_fe7a9_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.7%, transparent 27.7%);
# }
# #T_fe7a9_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.2%, transparent 11.2%);
# }
# #T_fe7a9_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.0%, transparent 9.0%);
# }
# #T_fe7a9_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.0%, transparent 22.0%);
# }
# #T_fe7a9_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.0%, transparent 14.0%);
# }
# #T_fe7a9_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.2%, transparent 78.2%);
# }
# </style>
# <table id="T_fe7a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe7a9_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_fe7a9_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_fe7a9_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_fe7a9_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_fe7a9_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_fe7a9_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe7a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe7a9_row0_col0" class="data row0 col0" >0.203441</td>
#       <td id="T_fe7a9_row0_col1" class="data row0 col1" >1.579559</td>
#       <td id="T_fe7a9_row0_col2" class="data row0 col2" >0.076420</td>
#       <td id="T_fe7a9_row0_col3" class="data row0 col3" >2.270737</td>
#       <td id="T_fe7a9_row0_col4" class="data row0 col4" >1.459605</td>
#       <td id="T_fe7a9_row0_col5" class="data row0 col5" >0.576294</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe7a9_row1_col0" class="data row1 col0" >0.493965</td>
#       <td id="T_fe7a9_row1_col1" class="data row1 col1" >0.950349</td>
#       <td id="T_fe7a9_row1_col2" class="data row1 col2" >1.612466</td>
#       <td id="T_fe7a9_row1_col3" class="data row1 col3" >0.232065</td>
#       <td id="T_fe7a9_row1_col4" class="data row1 col4" >0.158511</td>
#       <td id="T_fe7a9_row1_col5" class="data row1 col5" >1.676749</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe7a9_row2_col0" class="data row2 col0" >0.295816</td>
#       <td id="T_fe7a9_row2_col1" class="data row2 col1" >0.367696</td>
#       <td id="T_fe7a9_row2_col2" class="data row2 col2" >0.860680</td>
#       <td id="T_fe7a9_row2_col3" class="data row2 col3" >2.023045</td>
#       <td id="T_fe7a9_row2_col4" class="data row2 col4" >1.187149</td>
#       <td id="T_fe7a9_row2_col5" class="data row2 col5" >0.417573</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe7a9_row3_col0" class="data row3 col0" >0.675255</td>
#       <td id="T_fe7a9_row3_col1" class="data row3 col1" >1.599868</td>
#       <td id="T_fe7a9_row3_col2" class="data row3 col2" >0.171656</td>
#       <td id="T_fe7a9_row3_col3" class="data row3 col3" >0.878916</td>
#       <td id="T_fe7a9_row3_col4" class="data row3 col4" >0.836571</td>
#       <td id="T_fe7a9_row3_col5" class="data row3 col5" >0.137732</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fe7a9_row4_col0" class="data row4 col0" >0.458623</td>
#       <td id="T_fe7a9_row4_col1" class="data row4 col1" >0.337565</td>
#       <td id="T_fe7a9_row4_col2" class="data row4 col2" >1.120269</td>
#       <td id="T_fe7a9_row4_col3" class="data row4 col3" >0.041328</td>
#       <td id="T_fe7a9_row4_col4" class="data row4 col4" >1.401812</td>
#       <td id="T_fe7a9_row4_col5" class="data row4 col5" >0.610949</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fe7a9_row5_col0" class="data row5 col0" >0.261927</td>
#       <td id="T_fe7a9_row5_col1" class="data row5 col1" >0.006816</td>
#       <td id="T_fe7a9_row5_col2" class="data row5 col2" >0.230570</td>
#       <td id="T_fe7a9_row5_col3" class="data row5 col3" >0.587268</td>
#       <td id="T_fe7a9_row5_col4" class="data row5 col4" >0.361588</td>
#       <td id="T_fe7a9_row5_col5" class="data row5 col5" >1.475556</td>
#     </tr>
#   </tbody>
# </table>

# %%
head = {"selector": "th", "props": [("text-align", "center")]}
df.style.set_table_styles([head]).bar(align="mid", color=['red', 'green'], vmin=-3, vmax=3)
# Out:
# <style type="text/css">
# #T_664dd th {
#   text-align: center;
# }
# #T_664dd_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 53.4%, transparent 53.4%);
# }
# #T_664dd_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.7%, red 23.7%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.3%, transparent 51.3%);
# }
# #T_664dd_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 87.8%, transparent 87.8%);
# }
# #T_664dd_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 74.3%, transparent 74.3%);
# }
# #T_664dd_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 59.6%, transparent 59.6%);
# }
# #T_664dd_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.8%, red 41.8%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.2%, red 34.2%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 76.9%, transparent 76.9%);
# }
# #T_664dd_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.1%, red 46.1%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 52.6%, transparent 52.6%);
# }
# #T_664dd_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.1%, red 22.1%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.1%, red 45.1%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.9%, red 43.9%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.7%, red 35.7%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 83.7%, transparent 83.7%);
# }
# #T_664dd_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.2%, red 30.2%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.0%, red 43.0%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 61.3%, transparent 61.3%);
# }
# #T_664dd_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 76.7%, transparent 76.7%);
# }
# #T_664dd_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 52.9%, transparent 52.9%);
# }
# #T_664dd_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.4%, red 35.4%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 63.9%, transparent 63.9%);
# }
# #T_664dd_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.7%, red 47.7%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.4%, red 42.4%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.4%, red 44.4%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.3%, red 31.3%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 50.7%, transparent 50.7%);
# }
# #T_664dd_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.6%, red 26.6%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.8%, red 39.8%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 54.4%, transparent 54.4%);
# }
# #T_664dd_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.9%, red 49.9%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 53.8%, transparent 53.8%);
# }
# #T_664dd_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.2%, red 40.2%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.0%, red 44.0%, red 50.0%, transparent 50.0%);
# }
# #T_664dd_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 74.6%, transparent 74.6%);
# }
# </style>
# <table id="T_664dd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_664dd_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_664dd_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_664dd_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_664dd_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_664dd_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_664dd_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_664dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_664dd_row0_col0" class="data row0 col0" >0.203441</td>
#       <td id="T_664dd_row0_col1" class="data row0 col1" >-1.579559</td>
#       <td id="T_664dd_row0_col2" class="data row0 col2" >0.076420</td>
#       <td id="T_664dd_row0_col3" class="data row0 col3" >2.270737</td>
#       <td id="T_664dd_row0_col4" class="data row0 col4" >1.459605</td>
#       <td id="T_664dd_row0_col5" class="data row0 col5" >0.576294</td>
#     </tr>
#     <tr>
#       <th id="T_664dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_664dd_row1_col0" class="data row1 col0" >-0.493965</td>
#       <td id="T_664dd_row1_col1" class="data row1 col1" >-0.950349</td>
#       <td id="T_664dd_row1_col2" class="data row1 col2" >1.612466</td>
#       <td id="T_664dd_row1_col3" class="data row1 col3" >-0.232065</td>
#       <td id="T_664dd_row1_col4" class="data row1 col4" >0.158511</td>
#       <td id="T_664dd_row1_col5" class="data row1 col5" >-1.676749</td>
#     </tr>
#     <tr>
#       <th id="T_664dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_664dd_row2_col0" class="data row2 col0" >-0.295816</td>
#       <td id="T_664dd_row2_col1" class="data row2 col1" >-0.367696</td>
#       <td id="T_664dd_row2_col2" class="data row2 col2" >-0.860680</td>
#       <td id="T_664dd_row2_col3" class="data row2 col3" >2.023045</td>
#       <td id="T_664dd_row2_col4" class="data row2 col4" >-1.187149</td>
#       <td id="T_664dd_row2_col5" class="data row2 col5" >-0.417573</td>
#     </tr>
#     <tr>
#       <th id="T_664dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_664dd_row3_col0" class="data row3 col0" >0.675255</td>
#       <td id="T_664dd_row3_col1" class="data row3 col1" >1.599868</td>
#       <td id="T_664dd_row3_col2" class="data row3 col2" >0.171656</td>
#       <td id="T_664dd_row3_col3" class="data row3 col3" >-0.878916</td>
#       <td id="T_664dd_row3_col4" class="data row3 col4" >0.836571</td>
#       <td id="T_664dd_row3_col5" class="data row3 col5" >-0.137732</td>
#     </tr>
#     <tr>
#       <th id="T_664dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_664dd_row4_col0" class="data row4 col0" >-0.458623</td>
#       <td id="T_664dd_row4_col1" class="data row4 col1" >-0.337565</td>
#       <td id="T_664dd_row4_col2" class="data row4 col2" >-1.120269

# %%
df.style.bar(align="mid", width=50).apply(gold_max, axis=None).applymap(neg_red)
# Out:
# /tmp/ipykernel_279/3665736045.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df.style.bar(align="mid", width=50).apply(gold_max, axis=None).applymap(neg_red)
# <style type="text/css">
# #T_7d06a_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.1%, #d65f5f 21.1%, #d65f5f 29.8%, transparent 29.8%);
#   color: green;
# }
# #T_7d06a_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.8%, transparent 24.8%);
#   color: red;
# }
# #T_7d06a_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.5%, #d65f5f 20.5%, #d65f5f 21.9%, transparent 21.9%);
#   color: green;
# }
# #T_7d06a_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 14.0%, #d65f5f 14.0%, #d65f5f 50.0%, transparent 50.0%);
#   background-color: #c78f2e;
#   color: green;
# }
# #T_7d06a_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.5%, #d65f5f 24.5%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# #T_7d06a_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.6%, #d65f5f 26.6%, #d65f5f 35.7%, transparent 35.7%);
#   color: green;
# }
# #T_7d06a_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.1%, transparent 21.1%);
#   color: red;
# }
# #T_7d06a_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 9.9%, #d65f5f 9.9%, #d65f5f 24.8%, transparent 24.8%);
#   color: red;
# }
# #T_7d06a_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.5%, #d65f5f 20.5%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# #T_7d06a_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 10.3%, #d65f5f 10.3%, #d65f5f 14.0%, transparent 14.0%);
#   color: red;
# }
# #T_7d06a_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.5%, #d65f5f 24.5%, #d65f5f 27.3%, transparent 27.3%);
#   color: green;
# }
# #T_7d06a_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.6%, transparent 26.6%);
#   color: red;
# }
# #T_7d06a_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.5%, #d65f5f 8.5%, #d65f5f 21.1%, transparent 21.1%);
#   color: red;
# }
# #T_7d06a_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 19.1%, #d65f5f 19.1%, #d65f5f 24.8%, transparent 24.8%);
#   color: red;
# }
# #T_7d06a_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.7%, #d65f5f 4.7%, #d65f5f 20.5%, transparent 20.5%);
#   color: red;
# }
# #T_7d06a_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 14.0%, #d65f5f 14.0%, #d65f5f 46.1%, transparent 46.1%);
#   color: green;
# }
# #T_7d06a_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.8%, #d65f5f 3.8%, #d65f5f 24.5%, transparent 24.5%);
#   color: red;
# }
# #T_7d06a_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.0%, #d65f5f 20.0%, #d65f5f 26.6%, transparent 26.6%);
#   color: red;
# }
# #T_7d06a_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.1%, #d65f5f 21.1%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# #T_7d06a_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.8%, #d65f5f 24.8%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# #T_7d06a_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.5%, #d65f5f 20.5%, #d65f5f 23.6%, transparent 23.6%);
#   color: green;
# }
# #T_7d06a_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.0%, transparent 14.0%);
#   color: red;
# }
# #T_7d06a_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.5%, #d65f5f 24.5%, #d65f5f 39.1%, transparent 39.1%);
#   color: green;
# }
# #T_7d06a_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.4%, #d65f5f 24.4%, #d65f5f 26.6%, transparent 26.6%);
#   color: red;
# }
# #T_7d06a_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 1.5%, #d65f5f 1.5%, #d65f5f 21.1%, transparent 21.1%);
#   color: red;
# }
# #T_7d06a_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 19.5%, #d65f5f 19.5%, #d65f5f 24.8%, transparent 24.8%);
#   color: red;
# }
# #T_7d06a_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.5%, transparent 20.5%);
#   color: red;
# }
# #T_7d06a_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 14.0%, #d65f5f 14.0%, #d65f5f 14.6%, transparent 14.6%);
#   color: green;
# }
# #T_7d06a_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.5%, transparent 24.5%);
#   color: red;
# }
# #T_7d06a_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.9%, #d65f5f 16.9%, #d65f5f 26.6%, transparent 26.6%);
#   color: red;
# }
# #T_7d06a_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.1%, #d65f5f 21.1%, #d65f5f 32.3%, transparent 32.3%);
#   color: green;
# }
# #T_7d06a_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.7%, #d65f5f 24.7%, #d65f5f 24.8%, transparent 24.8%);
#   color: red;
# }
# #T_7d06a_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.5%, #d65f5f 20.5%, #d65f5f 24.7%, transparent 24.7%);
#   color: green;
# }
# #T_7d06a_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.6%, #d65f5f 4.6%, #d65f5f 14.0%, transparent 14.0%);
#   color: red;
# }
# #T_7d06a_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.2%, #d65f5f 18.2%, #d65f5f 24.5%, transparent 24.5%);
#   color: red;
# }
# #T_7d06a_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.6%, #d65f5f 26.6%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# </style>
# <table id="T_7d06a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d06a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7d06a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_7d06a_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_7d06a_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_7d06a_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_7d06a_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d06a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d06a_row0_col0" class="data row0 col0" >0.203441</td>
#       <td id="T_7d06a_row0_col1" class="data row0 col1" >-1.579559</td>
#       <td id="T_7d06a_row0_col2" class="data row0 col2" >0.076420</td>
#       <td id="T_7d06a_row0_col3" class="data row0 col3" >2.270737</td>
#       <td id="T_7d06a_row0_col4" class="data row0 col4" >1.459605</td>
#       <td id="T_7d06a_row0_col5" class="data row0 col5" >0.576294</td>
#     </tr>
#     <tr>
#       <th id="T_7d06a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d06a_row1_col0" class="data row1 col0" >-0.493965</td>
#       <td id="T_7d06a_row1_col1" class="data row1 col1" >-0.950349</td>
#       <td id="T_7d06a_row1_col2" class="data row1 col2" >1.612466</td>
#       <td id="T_7d06a_row1_col3" class="data row1 col3" >-0.232065</td>
#       <td id="T_7d06a_row1_col4" class="data row1 col4" >0.158511</td>
#       <td id="T_7d06a_row1_col5" class="data row1 col5" >-1.676749</td>
#     </tr>
#     <tr>
#       <th id="T_7d06a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d06a_row2_col0" class="data row2 col0" >-0.295816</td>
#       <td id="T_7d06a_row2_col1" class="data row2 col1" >-0.367696</td>
#       <td id="T_7d06a_row2_col2" class="data row2 col2" >-0.860680</td>
#       <td id="T_7d06a_row2_col3" class="data row2 col3" >2.023045</td>
#       <td id="T_7d06a_row2_col4" class="data row2 col4" >-1.187149</td>
#       <td id="T_7d06a_row2_col5" class="data row2 col5" >-0.417573</td>
#     </tr>
#     <tr>
#       <th id="T_7d06a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d06a_row3_col0" class="data row3 col0" >0.675255</td>
#       <td id="T_7d06a_row3_col1" class="data row3 col1" >1.599868</td>
#       <td id="T_7d06a_row3_col2" class="data row3 col2"
